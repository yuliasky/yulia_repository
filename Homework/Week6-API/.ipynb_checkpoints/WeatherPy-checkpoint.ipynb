# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %%
cities
# Out:
# ['illoqqortoormiut',
#  'kondinskoye',
#  'kapaa',
#  'katobu',
#  'avera',
#  'takoradi',
#  'saint-pierre',
#  'mataura',
#  'saint-leu',
#  'puerto ayora',
#  'hasaki',
#  'san cristobal',
#  'bluff',
#  'souillac',
#  'yatou',
#  'lansdale',
#  'busselton',
#  'punta arenas',
#  'cabo san lucas',
#  'nishihara',
#  'kruisfontein',
#  'aswan',
#  'tasiilaq',
#  'oskemen',
#  'ushuaia',
#  'bredasdorp',
#  'thompson',
#  'taltal',
#  'mys shmidta',
#  'barrow',
#  'grand river south east',
#  'hobart',
#  'east london',
#  'carnarvon',
#  'albany',
#  'port alfred',
#  'novovarshavka',
#  'avarua',
#  'tumannyy',
#  'qaanaaq',
#  'hilo',
#  'singleton',
#  'gushikawa',
#  'rikitea',
#  'kuytun',
#  'xai-xai',
#  'grinnell',
#  'matay',
#  'longyearbyen',
#  'samusu',
#  'hermanus',
#  'partizanskoye',
#  'laguna',
#  'kailua',
#  'talovaya',
#  'flinders',
#  'cape town',
#  'pangnirtung',
#  'altay',
#  'terenos',
#  'belushya guba',
#  'arraial do cabo',
#  'hongjiang',
#  'katsuura',
#  'yulara',
#  'aklavik',
#  'torbay',
#  'oriximina',
#  'balakliya',
#  'hualmay',
#  'barentsburg',
#  'fortuna',
#  'khatanga',
#  'cap malheureux',
#  'taolanaro',
#  'tual',
#  'tuktoyaktuk',
#  'maragogi',
#  'pakwach',
#  'hirara',
#  'swellendam',
#  'basco',
#  'vila velha',
#  'huarmey',
#  'moroni',
#  'uhlove',
#  'atuona',
#  'nizhneyansk',
#  'srandakan',
#  'winchester',
#  'mbarara',
#  'luderitz',
#  'goderich',
#  'ribeira grande',
#  'provideniya',
#  'pokrovsk-uralskiy',
#  'klaksvik',
#  'skjervoy',
#  'portland',
#  'marcona',
#  'ust-kuyga',
#  'tucupita',
#  'pevek',
#  'sitka',
#  'hamilton',
#  'bengkulu',
#  'westerland',
#  'meyungs',
#  'kenai',
#  'chimbote',
#  'sakakah',
#  'brae',
#  'kirakira',
#  'vaini',
#  'axim',
#  'lebu',
#  'bechem',
#  'saint-philippe',
#  'uvalde',
#  'ler',
#  'coquimbo',
#  'vaitupu',
#  'college',
#  'dawlatabad',
#  'galgani',
#  'makat',
#  'ilinsko-podomskoye',
#  'kosonsoy',
#  'maldonado',
#  'castro',
#  'moiyabana',
#  'hattiesburg',
#  'inhambane',
#  'aksarka',
#  'atar',
#  'fonte boa',
#  'ternate',
#  'morant bay',
#  'karaul',
#  'lagoa',
#  'ayan',
#  'sioux lookout',
#  'barra da estiva',
#  'naze',
#  'damghan',
#  'kieta',
#  'nanortalik',
#  'umzimvubu',
#  'tiksi',
#  'talnakh',
#  'georgetown',
#  'sept-iles',
#  'derzhavinsk',
#  'tessalit',
#  'perevoz',
#  'luganville',
#  'sao filipe',
#  'pacific grove',
#  'doctor pedro p. pena',
#  'guerrero negro',
#  'yerbogachen',
#  'esperance',
#  'zhigansk',
#  'narsaq',
#  'attawapiskat',
#  'tra vinh',
#  'camana',
#  'nikolskoye',
#  'spassk',
#  'mar del plata',
#  'amderma',
#  'butaritari',
#  'kavaratti',
#  'kodiak',
#  'petropavlovsk-kamchatskiy',
#  'jamestown',
#  'alofi',
#  'isangel',
#  'upernavik',
#  'mahebourg',
#  'churapcha',
#  'north platte',
#  'priargunsk',
#  'gat',
#  'fevralsk',
#  'lasa',
#  'geraldton',
#  'djenne',
#  'saleaula',
#  'new norfolk',
#  'tolaga bay',
#  'namie',
#  'gizo',
#  'mogok',
#  'saskylakh',
#  'sydney',
#  'hondo',
#  'ziarat',
#  'kracheh',
#  'chinsali',
#  'port elizabeth',
#  'kudat',
#  'tautira',
#  'porto novo',
#  'kaitangata',
#  'komsomolskiy',
#  'half moon bay',
#  'verkhnyaya inta',
#  'belmonte',
#  'yellowknife',
#  'ust-tarka',
#  'pisco',
#  'moerai',
#  'dingle',
#  'tarudant',
#  'konstantinovka',
#  'mpika',
#  'neftegorsk',
#  'baracoa',
#  'bogorodskoye',
#  'havre-saint-pierre',
#  'alyangula',
#  'harper',
#  'ilulissat',
#  'ostrovnoy',
#  'husavik',
#  'atherton',
#  'bathsheba',
#  'bambous virieux',
#  'balkanabat',
#  'grants',
#  'fort nelson',
#  'mbandaka',
#  'hithadhoo',
#  'fairbanks',
#  'sumbawa',
#  'grants pass',
#  'severo-kurilsk',
#  'la rioja',
#  'sinnamary',
#  'kostino',
#  'tumut',
#  'yar-sale',
#  'cuamba',
#  'dunedin',
#  'sentyabrskiy',
#  'lorengau',
#  'watsa',
#  'bandarbeyla',
#  'hovd',
#  'karlstad',
#  'sena madureira',
#  'manokwari',
#  'hambantota',
#  'poya',
#  'bol',
#  'cururupu',
#  'marzuq',
#  'tsihombe',
#  'saint combs',
#  'azimur',
#  'voskevan',
#  'lamar',
#  'yialos',
#  'belyy yar',
#  'san patricio',
#  'paamiut',
#  'henties bay',
#  'shelburne',
#  'stornoway',
#  'rungata',
#  'santa eulalia del rio',
#  'chuy',
#  'makokou',
#  'evora',
#  'atasu',
#  'dikson',
#  'cadillac',
#  'vamvakofiton',
#  'caravelas',
#  'port hedland',
#  'flin flon',
#  'teya',
#  'raudeberg',
#  'port lincoln',
#  'bolshaya martynovka',
#  'benguela',
#  'kampene',
#  'micco',
#  'elko',
#  'moranbah',
#  'biak',
#  'arsikere',
#  'ketchikan',
#  'goure',
#  'merauke',
#  'faanui',
#  'moundou',
#  'sweetwater',
#  'antofagasta',
#  'tuatapere',
#  'jacareacanga',
#  'sabang',
#  'naryan-mar',
#  'oyama',
#  'bitung',
#  'airai',
#  'huron',
#  'mitu',
#  'tromso',
#  'aden',
#  'yomitan',
#  'puerto colombia',
#  'mutsamudu',
#  'sakhipur',
#  'gorontalo',
#  'locri',
#  'camacha',
#  'inuvik',
#  'umm lajj',
#  'cherskiy',
#  'bethel',
#  'lyubech',
#  'coahuayana',
#  'kaka',
#  'ngukurr',
#  'plettenberg bay',
#  'norman wells',
#  'halifax',
#  'brookings',
#  'rocha',
#  'lugovoy',
#  'nikolsk',
#  'pangkalanbuun',
#  'smithville',
#  'maitum',
#  'turayf',
#  'morro bay',
#  'luena',
#  'dolgoye',
#  'cockburn town',
#  'belmopan',
#  'bacuit',
#  'tubruq',
#  'ahuimanu',
#  'aracuai',
#  'durban',
#  'winsum',
#  'ribeira brava',
#  'nizhnyaya tura',
#  'pyaozerskiy',
#  'olga',
#  'ulaangom',
#  'si sa ket',
#  'grand centre',
#  'cooma',
#  'ponta do sol',
#  'poso',
#  'mishkino',
#  'tahoua',
#  'tsentralnyy',
#  'zaysan',
#  'turukhansk',
#  'chokurdakh',
#  'saldanha',
#  'port hueneme',
#  'sorong',
#  'gobabis',
#  'warmbad',
#  'tiarei',
#  'shenjiamen',
#  'puerto leguizamo',
#  'aykhal',
#  'vao',
#  'okrisky',
#  'ahipara',
#  'flic en flac',
#  'leningradskiy',
#  'whitianga',
#  'samarai',
#  'cienfuegos',
#  'port moresby',
#  'bam',
#  'nargana',
#  'canatlan',
#  'casper',
#  'jalu',
#  'mogadishu',
#  'bernardino de campos',
#  'waipawa',
#  'rawson',
#  'grajau',
#  'jian',
#  'port hardy',
#  'brownwood',
#  'nador',
#  'vila franca do campo',
#  'batagay-alyta',
#  'albesti',
#  'guinguineo',
#  'fallon',
#  'grindavik',
#  'inverness',
#  'baiyin',
#  'plunge',
#  'kindu',
#  'ossora',
#  'ozgon',
#  'cidreira',
#  'rehoboth',
#  'mahibadhoo',
#  'margherita di savoia',
#  'saint-augustin',
#  'sao joao da barra',
#  'rocky mountain house',
#  'roebourne',
#  'verkhnetulomskiy',
#  'safaga',
#  'puri',
#  'mujiayingzi',
#  'artyk',
#  'le robert',
#  'khani',
#  'mumford',
#  'talas',
#  'juifang',
#  'los llanos de aridane',
#  'svetlaya',
#  'djibo',
#  'miyako',
#  'carmen de viboral',
#  'port-gentil',
#  'waingapu',
#  'olinda',
#  'tulum',
#  'lompoc',
#  'teguldet',
#  'omboue',
#  'bilgoraj',
#  'muana',
#  'uthal',
#  'nome',
#  'acapulco',
#  'charters towers',
#  'verkhoyansk',
#  'bolungarvik',
#  'makubetsu',
#  'baykit',
#  'zheleznodorozhnyy',
#  'vanimo',
#  'wajima',
#  'bentiu',
#  'buraydah',
#  'okhotsk',
#  'bayan',
#  'felidhoo',
#  'namatanai',
#  'loandjili',
#  'suhbaatar',
#  'oranjestad',
#  'barth',
#  'cheuskiny',
#  'samdari',
#  'hervey bay',
#  'riachao das neves',
#  'saint george',
#  'vestmannaeyjar',
#  'petit goave',
#  'sola',
#  'san policarpo',
#  'banda aceh',
#  'warqla',
#  'aflu',
#  'imbituba',
#  'kuryk',
#  'burnie',
#  'kropotkin',
#  'birjand',
#  'vranov',
#  'anloga',
#  'cayenne',
#  'karratha',
#  'lesnoy',
#  'canto do buriti',
#  'yarada',
#  'ambunti',
#  'necochea',
#  'seoul',
#  'palasa',
#  'lavrentiya',
#  'melfort',
#  'juneau',
#  'tilichiki',
#  'san quintin',
#  'agadez',
#  'codrington',
#  'pitimbu',
#  'provost',
#  'carballo',
#  'helong',
#  'laranjeiras do sul',
#  'mullaitivu',
#  'beloit',
#  'sambava',
#  'costache negri',
#  'chapais',
#  'chagda',
#  'miri',
#  'sibolga',
#  'santa cruz',
#  'burma',
#  'udachnyy',
#  'kautokeino',
#  'bubaque',
#  'bukachacha',
#  'klyuchi',
#  'tiznit',
#  'pozo colorado',
#  'palmer',
#  'victoria',
#  'micheweni',
#  'puerto escondido',
#  'roald',
#  'poum',
#  'mandalgovi',
#  'lata',
#  'mitchell',
#  'champerico',
#  'port macquarie',
#  'svetlogorsk',
#  'kahului',
#  'sechura',
#  'altus',
#  'lewisville',
#  'banff',
#  'elizabeth city',
#  'ballina',
#  'hanzhong',
#  'upington',
#  'gimbi',
#  'salalah',
#  'suseni',
#  'deder',
#  'asau',
#  'bangarmau',
#  'levelland',
#  'loa janan',
#  'padang',
#  'clevelandia',
#  'adrar',
#  'yorosso',
#  'sembe',
#  'baoro',
#  'menongue',
#  'oktyabrskiy',
#  'artesia',
#  'urucui',
#  'iqaluit',
#  'dzhusaly',
#  'mecca',
#  'viligili',
#  'kavieng',
#  'krasnoselkup',
#  'podeni',
#  'hirado',
#  'nemuro',
#  'concepcion del oro',
#  'sovetskiy',
#  'meyrin',
#  'bulgan',
#  'banjar',
#  'sunrise manor',
#  'buin',
#  'santa maria',
#  'buala',
#  'chake chake',
#  'cholet',
#  'djambala',
#  'nhulunbuy',
#  'mehamn',
#  'guanica',
#  'samoded',
#  'namibe',
#  'noumea',
#  'richards bay',
#  'zahesi',
#  'staryy biser',
#  'brigg']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# set up lisst to hold information
temperatures = []
longitudes = []
latitudes = []
clouds = []
wind_speeds = []
countries = []
humidities = []
dates = []
cities_found = []

print("Beginning Data Retrieval")
print("-----------------------------")
cont=1

for city in cities:
    # Build query URL and request your results in Celsius
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    
    # Get weather data
    weather_response = requests.get(query_url)
    
    if weather_response.status_code == 200:
        print(f"Processing Record {cont} | {city}")
        weather_json = weather_response.json()
        
        # Get temperature from JSON response
        cities_found.append(city)
        temperature = weather_json["main"]["temp_max"]
        temperatures.append(temperature)
        longitude = weather_json["coord"]["lon"]
        longitudes.append(longitude)
        latitude = weather_json["coord"]["lat"]
        latitudes.append(latitude)
        cloud = weather_json["clouds"]["all"]
        clouds.append(cloud)
        wind_speed = weather_json["wind"]["speed"]
        wind_speeds.append(wind_speed)
        country = weather_json["sys"]["country"]
        countries.append(country)
        humidity = weather_json["main"]["humidity"]
        humidities.append(humidity)
        date = weather_json["dt"]
        dates.append(date)
        
        cont=cont+1
    elif weather_response.status_code == 404:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 | kondinskoye
# Processing Record 2 | kapaa
# Processing Record 3 | katobu
# Processing Record 4 | avera
# Processing Record 5 | takoradi
# Processing Record 6 | saint-pierre
# Processing Record 7 | mataura
# Processing Record 8 | saint-leu
# Processing Record 9 | puerto ayora
# Processing Record 10 | hasaki
# Processing Record 11 | san cristobal
# Processing Record 12 | bluff
# Processing Record 13 | souillac
# Processing Record 14 | yatou
# Processing Record 15 | lansdale
# Processing Record 16 | busselton
# Processing Record 17 | punta arenas
# Processing Record 18 | cabo san lucas
# Processing Record 19 | nishihara
# Processing Record 20 | kruisfontein
# Processing Record 21 | aswan
# Processing Record 22 | tasiilaq
# Processing Record 23 | oskemen
# Processing Record 24 | ushuaia
# Processing Record 25 | bredasdorp
# Processing Record 26 | thompson
# Processing Record 27 | taltal
# City not found. Skipping...
# Processing Record 28 | barrow
# City not found. Skipping...
# Processing Record 29 | hobart
# Processing Record 30 | east london
# Processing Record 31 | carnarvon
# Processing Record 32 | albany
# Processing Record 33 | port alfred
# Processing Record 34 | novovarshavka
# Processing Record 35 | avarua
# City not found. Skipping...
# Processing Record 36 | qaanaaq
# Processing Record 37 | hilo
# Processing Record 38 | singleton
# Processing Record 39 | gushikawa
# Processing Record 40 | rikitea
# Processing Record 41 | kuytun
# Processing Record 42 | xai-xai
# Processing Record 43 | grinnell
# Processing Record 44 | matay
# Processing Record 45 | longyearbyen
# City not found. Skipping...
# Processing Record 46 | hermanus
# Processing Record 47 | partizanskoye
# Processing Record 48 | laguna
# Processing Record 49 | kailua
# Processing Record 50 | talovaya
# Processing Record 51 | flinders
# Processing Record 52 | cape town
# Processing Record 53 | pangnirtung
# Processing Record 54 | altay
# Processing Record 55 | terenos
# City not found. Skipping...
# Processing Record 56 | arraial do cabo
# Processing Record 57 | hongjiang
# Processing Record 58 | katsuura
# Processing Record 59 | yulara
# Processing Record 60 | aklavik
# Processing Record 61 | torbay
# Processing Record 62 | oriximina
# Processing Record 63 | balakliya
# Processing Record 64 | hualmay
# City not found. Skipping...
# Processing Record 65 | fortuna
# Processing Record 66 | khatanga
# Processing Record 67 | cap malheureux
# City not found. Skipping...
# Processing Record 68 | tual
# Processing Record 69 | tuktoyaktuk
# Processing Record 70 | maragogi
# City not found. Skipping...
# Processing Record 71 | hirara
# Processing Record 72 | swellendam
# Processing Record 73 | basco
# Processing Record 74 | vila velha
# Processing Record 75 | huarmey
# Processing Record 76 | moroni
# Processing Record 77 | uhlove
# Processing Record 78 | atuona
# City not found. Skipping...
# Processing Record 79 | srandakan
# Processing Record 80 | winchester
# Processing Record 81 | mbarara
# Processing Record 82 | luderitz
# Processing Record 83 | goderich
# Processing Record 84 | ribeira grande
# Processing Record 85 | provideniya
# City not found. Skipping...
# Processing Record 86 | klaksvik
# Processing Record 87 | skjervoy
# Processing Record 88 | portland
# City not found. Skipping...
# Processing Record 89 | ust-kuyga
# Processing Record 90 | tucupita
# Processing Record 91 | pevek
# Processing Record 92 | sitka
# Processing Record 93 | hamilton
# City not found. Skipping...
# Processing Record 94 | westerland
# City not found. Skipping...
# Processing Record 95 | kenai
# Processing Record 96 | chimbote
# City not found. Skipping...
# Processing Record 97 | brae
# Processing Record 98 | kirakira
# Processing Record 99 | vaini
# Processing Record 100 | axim
# Processing Record 101 | lebu
# Processing Record 102 | bechem
# Processing Record 103 | saint-philippe
# Processing Record 104 | uvalde
# Processing Record 105 | ler
# Processing Record 106 | coquimbo
# City not found. Skipping...
# Processing Record 107 | college
# Processing Record 108 | dawlatabad
# City not found. Skipping...
# Processing Record 109 | makat
# City not found. Skipping...
# Processing Record 110 | kosonsoy
# Processing Record 111 | maldonado
# Processing Record 112 | castro
# City not found. Skipping...
# Processing Record 113 | hattiesburg
# Processing Record 114 | inhambane
# Processing Record 115 | aksarka
# Processing Record 116 | atar
# Processing Record 117 | fonte boa
# Processing Record 118 | ternate
# Processing Record 119 | morant bay
# City not found. Skipping...
# Processing Record 120 | lagoa
# Processing Record 121 | ayan
# Processing Record 122 | sioux lookout
# Processing Record 123 | barra da estiva
# Processing Record 124 | naze
# Processing Record 125 | damghan
# Processing Record 126 | kieta
# Processing Record 127 | nanortalik
# City not found. Skipping...
# Processing Record 128 | tiksi
# Processing Record 129 | talnakh
# Processing Record 130 | georgetown
# Processing Record 131 | sept-iles
# Processing Record 132 | derzhavinsk
# Processing Record 133 | tessalit
# Processing Record 134 | perevoz
# Processing Record 135 | luganville
# Processing Record 136 | sao filipe
# Processing Record 137 | pacific grove
# City not found. Skipping...
# Processing Record 138 | guerrero negro
# Processing Record 139 | yerbogachen
# Processing Record 140 | esperance
# Processing Record 141 | zhigansk
# Processing Record 142 | narsaq
# City not found. Skipping...
# Processing Record 143 | tra vinh
# City not found. Skipping...
# Processing Record 144 | nikolskoye
# Processing Record 145 | spassk
# Processing Record 146 | mar del plata
# City not found. Skipping...
# Processing Record 147 | butaritari
# Processing Record 148 | kavaratti
# Processing Record 149 | kodiak
# Processing Record 150 | petropavlovsk-kamchatskiy
# Processing Record 151 | jamestown
# Processing Record 152 | alofi
# Processing Record 153 | isangel
# Processing Record 154 | upernavik
# Processing Record 155 | mahebourg
# Processing Record 156 | churapcha
# Processing Record 157 | north platte
# Processing Record 158 | priargunsk
# Processing Record 159 | gat
# City not found. Skipping...
# Processing Record 160 | lasa
# Processing Record 161 | geraldton
# Processing Record 162 | djenne
# City not found. Skipping...
# Processing Record 163 | new norfolk
# Processing Record 164 | tolaga bay
# Processing Record 165 | namie
# Processing Record 166 | gizo
# Processing Record 167 | mogok
# Processing Record 168 | saskylakh
# Processing Record 169 | sydney
# Processing Record 170 | hondo
# Processing Record 171 | ziarat
# City not found. Skipping...
# Processing Record 172 | chinsali
# Processing Record 173 | port elizabeth
# Processing Record 174 | kudat
# Processing Record 175 | tautira
# Processing Record 176 | porto novo
# Processing Record 177 | kaitangata
# Processing Record 178 | komsomolskiy
# Processing Record 179 | half moon bay
# Processing Record 180 | verkhnyaya inta
# Processing Record 181 | belmonte
# Processing Record 182 | yellowknife
# Processing Record 183 | ust-tarka
# Processing Record 184 | pisco
# Processing Record 185 | moerai
# Processing Record 186 | dingle
# City not found. Skipping...
# Processing Record 187 | konstantinovka
# Processing Record 188 | mpika
# Processing Record 189 | neftegorsk
# Processing Record 190 | baracoa
# Processing Record 191 | bogorodskoye
# Processing Record 192 | havre-saint-pierre
# Processing Record 193 | alyangula
# Processing Record 194 | harper
# Processing Record 195 | ilulissat
# Processing Record 196 | ostrovnoy
# Processing Record 197 | husavik
# Processing Record 198 | atherton
# Processing Record 199 | bathsheba
# Processing Record 200 | bambous virieux
# Processing Record 201 | balkanabat
# Processing Record 202 | grants
# Processing Record 203 | fort nelson
# Processing Record 204 | mbandaka
# Processing Record 205 | hithadhoo
# Processing Record 206 | fairbanks
# City not found. Skipping...
# Processing Record 207 | grants pass
# Processing Record 208 | severo-kurilsk
# Processing Record 209 | la rioja
# Processing Record 210 | sinnamary
# Processing Record 211 | kostino
# Processing Record 212 | tumut
# Processing Record 213 | yar-sale
# Processing Record 214 | cuamba
# Processing Record 215 | dunedin
# City not found. Skipping...
# Processing Record 216 | lorengau
# Processing Record 217 | watsa
# Processing Record 218 | bandarbeyla
# Processing Record 219 | hovd
# Processing Record 220 | karlstad
# Processing Record 221 | sena madureira
# Processing Record 222 | manokwari
# Processing Record 223 | hambantota
# Processing Record 224 | poya
# Processing Record 225 | bol
# Processing Record 226 | cururupu
# Processing Record 227 | marzuq
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 228 | voskevan
# Processing Record 229 | lamar
# City not found. Skipping...
# Processing Record 230 | belyy yar
# Processing Record 231 | san patricio
# Processing Record 232 | paamiut
# Processing Record 233 | henties bay
# Processing Record 234 | shelburne
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 235 | chuy
# Processing Record 236 | makokou
# Processing Record 237 | evora
# Processing Record 238 | atasu
# Processing Record 239 | dikson
# Processing Record 240 | cadillac
# Processing Record 241 | vamvakofiton
# Processing Record 242 | caravelas
# Processing Record 243 | port hedland
# Processing Record 244 | flin flon
# Processing Record 245 | teya
# Processing Record 246 | raudeberg
# Processing Record 247 | port lincoln
# Processing Record 248 | bolshaya martynovka
# Processing Record 249 | benguela
# Processing Record 250 | kampene
# Processing Record 251 | micco
# Processing Record 252 | elko
# Processing Record 253 | moranbah
# Processing Record 254 | biak
# Processing Record 255 | arsikere
# Processing Record 256 | ketchikan
# Processing Record 257 | goure
# Processing Record 258 | merauke
# Processing Record 259 | faanui
# Processing Record 260 | moundou
# Processing Record 261 | sweetwater
# Processing Record 262 | antofagasta
# Processing Record 263 | tuatapere
# Processing Record 264 | jacareacanga
# Processing Record 265 | sabang
# Processing Record 266 | naryan-mar
# Processing Record 267 | oyama
# Processing Record 268 | bitung
# Processing Record 269 | airai
# Processing Record 270 | huron
# Processing Record 271 | mitu
# Processing Record 272 | tromso
# Processing Record 273 | aden
# City not found. Skipping...
# Processing Record 274 | puerto colombia
# City not found. Skipping...
# Processing Record 275 | sakhipur
# Processing Record 276 | gorontalo
# Processing Record 277 | locri
# Processing Record 278 | camacha
# Processing Record 279 | inuvik
# Processing Record 280 | umm lajj
# Processing Record 281 | cherskiy
# Processing Record 282 | bethel
# Processing Record 283 | lyubech
# Processing Record 284 | coahuayana
# Processing Record 285 | kaka
# City not found. Skipping...
# Processing Record 286 | plettenberg bay
# Processing Record 287 | norman wells
# Processing Record 288 | halifax
# Processing Record 289 | brookings
# Processing Record 290 | rocha
# Processing Record 291 | lugovoy
# Processing Record 292 | nikolsk
# Processing Record 293 | pangkalanbuun
# Processing Record 294 | smithville
# Processing Record 295 | maitum
# Processing Record 296 | turayf
# Processing Record 297 | morro bay
# Processing Record 298 | luena
# Processing Record 299 | dolgoye
# Processing Record 300 | cockburn town
# Processing Record 301 | belmopan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 302 | ahuimanu
# Processing Record 303 | aracuai
# Processing Record 304 | durban
# Processing Record 305 | winsum
# Processing Record 306 | ribeira brava
# Processing Record 307 | nizhnyaya tura
# Processing Record 308 | pyaozerskiy
# Processing Record 309 | olga
# Processing Record 310 | ulaangom
# Processing Record 311 | si sa ket
# City not found. Skipping...
# Processing Record 312 | cooma
# Processing Record 313 | ponta do sol
# Processing Record 314 | poso
# Processing Record 315 | mishkino
# Processing Record 316 | tahoua
# City not found. Skipping...
# Processing Record 317 | zaysan
# Processing Record 318 | turukhansk
# Processing Record 319 | chokurdakh
# Processing Record 320 | saldanha
# Processing Record 321 | port hueneme
# Processing Record 322 | sorong
# Processing Record 323 | gobabis
# Processing Record 324 | warmbad
# Processing Record 325 | tiarei
# Processing Record 326 | shenjiamen
# Processing Record 327 | puerto leguizamo
# Processing Record 328 | aykhal
# Processing Record 329 | vao
# Processing Record 330 | okrisky
# Processing Record 331 | ahipara
# Processing Record 332 | flic en flac
# Processing Record 333 | leningradskiy
# Processing Record 334 | whitianga
# Processing Record 335 | samarai
# Processing Record 336 | cienfuegos
# Processing Record 337 | port moresby
# Processing Record 338 | bam
# Processing Record 339 | nargana
# Processing Record 340 | canatlan
# Processing Record 341 | casper
# Processing Record 342 | jalu
# Processing Record 343 | mogadishu
# Processing Record 344 | bernardino de campos
# Processing Record 345 | waipawa
# Processing Record 346 | rawson
# City not found. Skipping...
# Processing Record 347 | jian
# Processing Record 348 | port hardy
# Processing Record 349 | brownwood
# Processing Record 350 | nador
# Processing Record 351 | vila franca do campo
# Processing Record 352 | batagay-alyta
# Processing Record 353 | albesti
# Processing Record 354 | guinguineo
# Processing Record 355 | fallon
# Processing Record 356 | grindavik
# Processing Record 357 | inverness
# Processing Record 358 | baiyin
# Processing Record 359 | plunge
# Processing Record 360 | kindu
# Processing Record 361 | ossora
# City not found. Skipping...
# Processing Record 362 | cidreira
# Processing Record 363 | rehoboth
# Processing Record 364 | mahibadhoo
# Processing Record 365 | margherita di savoia
# Processing Record 366 | saint-augustin
# Processing Record 367 | sao joao da barra
# Processing Record 368 | rocky mountain house
# Processing Record 369 | roebourne
# Processing Record 370 | verkhnetulomskiy
# City not found. Skipping...
# Processing Record 371 | puri
# Processing Record 372 | mujiayingzi
# City not found. Skipping...
# Processing Record 373 | le robert
# Processing Record 374 | khani
# Processing Record 375 | mumford
# Processing Record 376 | talas
# City not found. Skipping...
# Processing Record 377 | los llanos de aridane
# Processing Record 378 | svetlaya
# Processing Record 379 | djibo
# Processing Record 380 | miyako
# Processing Record 381 | carmen de viboral
# Processing Record 382 | port-gentil
# Processing Record 383 | waingapu
# Processing Record 384 | olinda
# Processing Record 385 | tulum
# Processing Record 386 | lompoc
# Processing Record 387 | teguldet
# Processing Record 388 | omboue
# Processing Record 389 | bilgoraj
# Processing Record 390 | muana
# Processing Record 391 | uthal
# Processing Record 392 | nome
# Processing Record 393 | acapulco
# Processing Record 394 | charters towers
# Processing Record 395 | verkhoyansk
# City not found. Skipping...
# Processing Record 396 | makubetsu
# Processing Record 397 | baykit
# Processing Record 398 | zheleznodorozhnyy
# Processing Record 399 | vanimo
# Processing Record 400 | wajima
# City not found. Skipping...
# Processing Record 401 | buraydah
# Processing Record 402 | okhotsk
# Processing Record 403 | bayan
# City not found. Skipping...
# Processing Record 404 | namatanai
# Processing Record 405 | loandjili
# Processing Record 406 | suhbaatar
# Processing Record 407 | oranjestad
# Processing Record 408 | barth
# City not found. Skipping...
# Processing Record 409 | samdari
# Processing Record 410 | hervey bay
# Processing Record 411 | riachao das neves
# Processing Record 412 | saint george
# Processing Record 413 | vestmannaeyjar
# Processing Record 414 | petit goave
# Processing Record 415 | sola
# Processing Record 416 | san policarpo
# Processing Record 417 | banda aceh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 418 | imbituba
# Processing Record 419 | kuryk
# Processing Record 420 | burnie
# Processing Record 421 | kropotkin
# Processing Record 422 | birjand
# Processing Record 423 | vranov
# Processing Record 424 | anloga
# Processing Record 425 | cayenne
# Processing Record 426 | karratha
# Processing Record 427 | lesnoy
# Processing Record 428 | canto do buriti
# Processing Record 429 | yarada
# Processing Record 430 | ambunti
# Processing Record 431 | necochea
# Processing Record 432 | seoul
# City not found. Skipping...
# Processing Record 433 | lavrentiya
# Processing Record 434 | melfort
# Processing Record 435 | juneau
# Processing Record 436 | tilichiki
# Processing Record 437 | san quintin
# Processing Record 438 | agadez
# Processing Record 439 | codrington
# Processing Record 440 | pitimbu
# Processing Record 441 | provost
# Processing Record 442 | carballo
# Processing Record 443 | helong
# Processing Record 444 | laranjeiras do sul
# City not found. Skipping...
# Processing Record 445 | beloit
# Processing Record 446 | sambava
# Processing Record 447 | costache negri
# Processing Record 448 | chapais
# City not found. Skipping...
# Processing Record 449 | miri
# Processing Record 450 | sibolga
# Processing Record 451 | santa cruz
# Processing Record 452 | burma
# Processing Record 453 | udachnyy
# Processing Record 454 | kautokeino
# Processing Record 455 | bubaque
# Processing Record 456 | bukachacha
# Processing Record 457 | klyuchi
# Processing Record 458 | tiznit
# Processing Record 459 | pozo colorado
# Processing Record 460 | palmer
# Processing Record 461 | victoria
# Processing Record 462 | micheweni
# Processing Record 463 | puerto escondido
# Processing Record 464 | roald
# Processing Record 465 | poum
# Processing Record 466 | mandalgovi
# Processing Record 467 | lata
# Processing Record 468 | mitchell
# Processing Record 469 | champerico
# Processing Record 470 | port macquarie
# Processing Record 471 | svetlogorsk
# Processing Record 472 | kahului
# Processing Record 473 | sechura
# Processing Record 474 | altus
# Processing Record 475 | lewisville
# Processing Record 476 | banff
# Processing Record 477 | elizabeth city
# Processing Record 478 | ballina
# Processing Record 479 | hanzhong
# Processing Record 480 | upington
# Processing Record 481 | gimbi
# Processing Record 482 | salalah
# Processing Record 483 | suseni
# Processing Record 484 | deder
# City not found. Skipping...
# Processing Record 485 | bangarmau
# Processing Record 486 | levelland
# Processing Record 487 | loa janan
# Processing Record 488 | padang
# Processing Record 489 | clevelandia
# Processing Record 490 | adrar
# Processing Record 491 | yorosso
# City not found. Skipping...
# Processing Record 492 | baoro
# Processing Record 493 | menongue
# Processing Record 494 | oktyabrskiy
# Processing Record 495 | artesia
# Processing Record 496 | urucui
# Processing Record 497 | iqaluit
# City not found. Skipping...
# Processing Record 498 | mecca
# City not found. Skipping...
# Processing Record 499 | kavieng
# City not found. Skipping...
# Processing Record 500 | podeni
# Processing Record 501 | hirado
# Processing Record 502 | nemuro
# Processing Record 503 | concepcion del oro
# Processing Record 504 | sovetskiy
# Processing Record 505 | meyrin
# Processing Record 506 | bulgan
# Processing Record 507 | banjar
# Processing Record 508 | sunrise manor
# Processing Record 509 | buin
# Processing Record 510 | santa maria
# Processing Record 511 | buala
# Processing Record 512 | chake chake
# Processing Record 513 | cholet
# Processing Record 514 | djambala
# Processing Record 515 | nhulunbuy
# Processing Record 516 | mehamn
# Processing Record 517 | guanica
# Processing Record 518 | samoded
# Processing Record 519 | namibe
# Processing Record 520 | noumea
# Processing Record 521 | richards bay
# Processing Record 522 | zahesi
# City not found. Skipping...
# Processing Record 523 | brigg

# %%
# zip the lists, create DataFrame and export to CSV
list_of_tuples = list(zip(cities_found,clouds,countries,dates,humidities,latitudes,longitudes,temperatures,wind_speeds))
df_cities = pd.DataFrame(list_of_tuples, columns = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed'])
df_cities.to_csv(output_data_file)
df_cities.count()
# Out:
# City          523
# Cloudiness    523
# Country       523
# Date          523
# Humidity      523
# Lat           523
# Lng           523
# Max Temp      523
# Wind Speed    523
# dtype: int64

# %%
df_cities.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  kondinskoye           4      RU  1563597418        50  59.65   67.41
# 1        kapaa          20      US  1563597437        74  22.08 -159.32
# 2       katobu          17      ID  1563597438        59  -4.94  122.53
# 3        avera           1      US  1563597438       100  33.19  -82.53
# 4     takoradi         100      GH  1563597438        92   4.89   -1.75
#
#    Max Temp  Wind Speed
# 0     81.95        8.97
# 1     86.00       14.99
# 2     85.73        6.98
# 3     80.60        4.36
# 4     74.03        3.62

# %%
# Store the date
readable = time.ctime(1563597418)
date_format=datetime.strptime(readable, "%a %b %d %H:%M:%S %Y")
date_format=str(date_format).split(' ')[0]
date_format=date_format.split('-')
date_format=date_format[1] + '/' + date_format[2] + '/' + date_format[0]
date_format
# Out:
# '07/19/2019'

# %%
# Scatter plot Latitude vs Temperature
lat_temp =  plt.scatter(df_cities["Lat"], df_cities["Max Temp"], c="coral",alpha=0.8, edgecolors="gray", linewidth=2, label='Max Temp')
title="City Latitude vs Max Temperature" + " (" + str(date_format) + ")"
plt.title(title)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()
plt.savefig("latitude_vs_temperature.png",bbox_inches="tight")
plt.show()

# %%
# Scatter plot Latitude vs Humidity
lat_hum =  plt.scatter(df_cities["Lat"], df_cities["Humidity"], c="blue",alpha=0.8, edgecolors="gray", linewidth=2, label='Max Temp')
title="City Latitude vs Humidity" + " (" + str(date_format) + ")"
plt.title(title)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()
plt.savefig("latitude_vs_humidity.png",bbox_inches="tight")
plt.show()

# %%
# Scatter plot Latitude vs Cloudiness
lat_cloud =  plt.scatter(df_cities["Lat"], df_cities["Cloudiness"], c="lightblue",alpha=0.8, edgecolors="gray", linewidth=2, label='Max Temp')
title="City Latitude vs Cloudiness" + " (" + str(date_format) + ")"
plt.title(title)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.tight_layout()
plt.savefig("latitude_vs_cloudiness.png",bbox_inches="tight")
plt.show()

# %%
# Scatter plot Latitude vs Wind Speed
lat_wind =  plt.scatter(df_cities["Lat"], df_cities["Wind Speed"], c="gold",alpha=0.8, edgecolors="gray", linewidth=2, label='Max Temp')
title="City Latitude vs Wind Speed" + " (" + str(date_format) + ")"
plt.title(title)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.tight_layout()
plt.savefig("latitude_vs_windspeed.png",bbox_inches="tight")
plt.show()

# %%
# Observable trends:
# - Higher temperature when the latitude is closer to Ecuator Line (Lat 0)
# - From Lat 0 to 20, the cloudiness trends to be higher and from -40 to 0 (south zone) trends to be lower
# - In the south zone, Lat -40 to 0, exists some higher points of Wind Speed (from 25 to 35 mph)
